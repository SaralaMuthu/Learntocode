# %% [markdown]
# <a href="https://colab.research.google.com/github/SaralaMuthu/Learntocode/blob/master/BPDFS_SNRGA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Feature Selection of BPD using SNR_LR_GA[Karthik Sir Work]**

# %% [markdown]
# https://github.com/karthiksekaran/autism-biomarker-discovery/blob/master/Classification.py

# %%
jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10
# Out:
#   File "<ipython-input-4-d3bfc748244a>", line 1
#     jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Autism Data GSE26415**

# %%
import pandas as pd
import numpy as np
dataset = pd.read_csv("/content/GSE26415.csv")
transpose = dataset.T
transpose.to_csv("Autismtrans.csv", header=False)
dataset = pd.read_csv("Autismtrans.csv")
del dataset['ID_REF']
dataset.to_csv("Autvalues.csv", index=None)
dataset = pd.read_csv("Autvalues.csv").values
#54613
l = []
temp = 0
sum = 0
avg = 0
count = 0
size = len(dataset)
average = []
for j in range(0, size):
    for i in dataset:
        temp = i[j]
        sum = sum + temp
    l.append(sum)
    temp = 0
    sum = 0
print("Stage-1")
std_calc = []
stdev = 0
stdev_res = []
std_calc_var = 0
for i in l:
    avg = i/size
    average.append(avg)
for j in range(0,size):
    for i in dataset:
        std_calc_var = i[j]
        std_calc.append(std_calc_var)
    stdev = np.std(std_calc, ddof=1)
    stdev_res.append(stdev)
    std_calc = []
print("Stage-2")
SNR = []
snr_val = 0
for i in range(0,len(average)):
    snr_val = average[i]/stdev_res[i]
    SNR.append(snr_val)
print(SNR)
print("Stage-3")
aver = 0
for i in SNR:
    aver = aver + i
aver = aver/len(SNR)
print("Threshold:",aver)
sigmoid = []
sig = 0
for i in SNR:
    sig = 1/(1+np.exp(-i))
    sigmoid.append(sig)
print(sigmoid)
print("Stage-4")
aveg = 0
for i in sigmoid:
    aveg = aveg+i
aveg = aveg/len(sigmoid)
print(aveg)
flag = 0
final = []
pos = []
for i in sigmoid:
    flag = flag+1
    if(i>aveg):
       final.append(i)
       pos.append(flag-1)
print(final)
print(pos)
print(len(final))
print("Stage-5")
import pandas as pd
dataset = pd.read_csv("Autvalues.csv")
l = []
for col in dataset.columns:
    l.append(col)
ind = []
for i in pos:
    ind.append(l[i])
print(ind)
csv_update = pd.DataFrame(ind)
csv_update.to_csv("Gene-List-Aut.csv", index=False)
# Out:
# Stage-1
# Stage-2
# [2.0522712808111923, 3.1406921189728165, 3.8239669621407986, 3.400313106354214, 3.6392722281176155, 2.6519357342597925, 2.507125064429345, 3.0687216992208293, 2.9561973226425557, 2.097990289967789, 2.0830788009504992, 3.8323891594215254, 3.7128919332571515, 2.8091971233575777, 3.9747009460775424, 3.7611600800103333, 3.4855437006661414, 2.7818307161778684, 1.1133396932580346, 3.314725617920434, 3.52221091335842, 3.1687522534191124, 3.885899790964569, 4.357673893522574, 4.4783366568888, 4.197315971284768, 2.911817165941529, 3.0423942289846098, 2.479697211987971, 4.293747822789967, 3.136812326038315, 3.5665930343081085, 4.184466766237745, 3.4664651748612725, 4.111061032764894, 3.22310719912814, 3.9034550075609102, 3.7145073585148674, 1.7424623058297828, 3.076170477902776, 3.8637877325486856, 4.720923300222283]
# Stage-3
# Threshold: 3.315595266739861
# ...

# %% [markdown]
# **Bipolar Data GSE46449**

# %%
import pandas as pd
import numpy as np
dataset = pd.read_csv("/content/drive/MyDrive/BPData/bpdFSclasss.csv")
transpose = dataset.T
transpose.to_csv("bpdtrans.csv", header=False)
dataset = pd.read_csv("bpdtrans.csv")
del dataset['ID']
dataset.to_csv("bpdvalues.csv", index=None)
dataset = pd.read_csv("bpdvalues.csv").values
#54613
l = []
temp = 0
sum = 0
avg = 0
count = 0
size = len(dataset)
average = []
for j in range(0, size):
    for i in dataset:
        temp = i[j]
        sum = sum + temp
    l.append(sum)
    temp = 0
    sum = 0
print("Stage-1")
std_calc = []
stdev = 0
stdev_res = []
std_calc_var = 0
for i in l:
    avg = i/size
    average.append(avg)
for j in range(0,size):
    for i in dataset:
        std_calc_var = i[j]
        std_calc.append(std_calc_var)
    stdev = np.std(std_calc, ddof=1)
    stdev_res.append(stdev)
    std_calc = []
print(stdev_res)
print("Stage-2")
SNR = []
snr_val = 0
for i in range(0,len(average)):
    snr_val = average[i]/stdev_res[i]
    SNR.append(snr_val)
print(SNR)
print("Stage-3")
aver = 0
for i in SNR:
    aver = aver + i
aver = aver/len(SNR)
print("Threshold:",aver)
sigmoid = []
sig = 0
for i in SNR:
    sig = 1/(1+np.exp(-i))
    sigmoid.append(sig)
print(sigmoid)
print("Stage-4")
aveg = 0
for i in sigmoid:
    aveg = aveg+i
aveg = aveg/len(sigmoid)
print(aveg)
flag = 0
final = []
pos = []
for i in sigmoid:
    flag = flag+1
    if(i>aveg):
       final.append(i)
       pos.append(flag-1)
print(final)
print(pos)
print(len(final))
print("Stage-5")
import pandas as pd
dataset = pd.read_csv("bpdvalues.csv")
l = []
for col in dataset.columns:
    l.append(col)
ind = []
for i in pos:
    ind.append(l[i])
print(ind)
csv_update = pd.DataFrame(ind)
csv_update.to_csv("Gene-List-bpd.csv", index=False)
# Out:
# Stage-1
# ...
